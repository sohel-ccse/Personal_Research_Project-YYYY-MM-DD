png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/206.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/278.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/18.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/33.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/271.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/530.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/316.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/506.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/181.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/256.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/150.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/652.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/476.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/568.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/413.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/69.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/94.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/605.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/188.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/250.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/344.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/301.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/425.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/333.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/105.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/156.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/315.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/244.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/185.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/66.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/152.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/191.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/342.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/235.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/592.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/280.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/670.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/36.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/357.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/173.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/310.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/56.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/493.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/269.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/331.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/595.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/667.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/564.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/90.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/689.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/201.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/157.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/441.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/688.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/140.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/560.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/661.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/538.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/151.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/238.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/32.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/28.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/513.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/402.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/455.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/715.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/246.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/386.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/636.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/30.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/55.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/204.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/563.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/404.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/248.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/205.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/299.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/369.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/542.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/565.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/220.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/659.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/10.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/537.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/635.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/394.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/134.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/418.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/602.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/449.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/533.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/142.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/115.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/598.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/39.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/700.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/89.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/249.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/356.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/444.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/703.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/37.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/47.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/387.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/420.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/620.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/648.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/645.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/561.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/282.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/629.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/341.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/464.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/263.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/489.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/713.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/27.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/23.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/336.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/277.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/662.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/85.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/666.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/177.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/54.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/370.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/473.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/346.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/385.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/445.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/681.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/440.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/82.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/525.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/106.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/591.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/552.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/58.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/306.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/421.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/218.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/65.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/654.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/24.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/12.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/424.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/29.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/143.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/507.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/197.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/114.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/687.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/285.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/427.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/15.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/545.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/276.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/641.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/411.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/50.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/210.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/675.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/199.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/527.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/557.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/166.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/665.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/81.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/706.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/119.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/472.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/175.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/99.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/159.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/43.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/339.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/410.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/213.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/468.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/345.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/716.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/243.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/398.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/454.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/168.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/651.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/6.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/623.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/431.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/75.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/599.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/296.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/367.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/649.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/318.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/683.png
# /kaggle/input/v2-plant-seedlings-dataset/Common Chickweed/61.png

# %%
# %env JOBLIB_TEMP_FOLDER=/tmp

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib import colors
import seaborn as sns
sns.set_style('whitegrid')

from PIL import Image
from imageio import imread
import imageio
import skimage
import skimage.io
import skimage.transform
from imageio import imread


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score

from skimage.morphology import closing, disk, opening
import random
import time
import copy
from tqdm import tqdm_notebook as tqdm
from os import listdir
import keras
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras.layers.normalization import BatchNormalization
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping, ReduceLROnPlateau

from keras import backend as K
from keras.models import Sequential
from keras.models import Model
from keras.layers import Activation
from keras.layers.core import Dense, Flatten
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.normalization import BatchNormalization
from keras.layers.core import Dropout
from keras.layers.convolutional import *
from keras.callbacks import ModelCheckpoint
from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input
from keras.applications.inception_v3 import decode_predictions
from sklearn.metrics import confusion_matrix
from sklearn.metrics import average_precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from keras.models import model_from_json
from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras import optimizers
from keras.models import Sequential, Model 
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.utils import np_utils
from keras.optimizers import SGD

from IPython.core.display import display, HTML
from PIL import Image
# Out:
# env: JOBLIB_TEMP_FOLDER=/tmp

# %%
from io import BytesIO
import base64

from os import listdir
from skimage.segmentation import mark_boundaries

import cv2

# %%
Directory='../input/v2-plant-seedlings-dataset/nonsegmentedv2/'
subfolders = listdir(Directory)
print(os.listdir('../input/v2-plant-seedlings-dataset/nonsegmentedv2/'))
# Out:
# ['Loose Silky-bent', 'Fat Hen', 'Charlock', 'Sugar beet', 'Shepherd’s Purse', 'Maize', 'Common wheat', 'Cleavers', 'Black-grass', 'Small-flowered Cranesbill', 'Scentless Mayweed', 'Common Chickweed']

# %%
sfc="Small-flowered Cranesbill"
plt.figure(figsize=(15,12))

for n in range(12):
        folder=subfolders[n]
        plt.subplot(3,4,n+1)
        files = listdir(Directory + folder + "/") 
        image=cv2.imread(Directory + folder + "/" + files[n+221])
        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        plt.axis("off")
        plt.title(folder, fontsize=14, weight='bold')

# %% [markdown]
# 1. After visualizing the images, we have an idea of the how to deal with this project:
# 1.
# 1. Aim: Classify the plant species images so that the machine distinguishes between crop seedlings and weed.
# 1.
# 1. Challenge: The images include some stones in the background, we don't want the machine to learn the stones pixels and base its prediction on all the components of the image: seedlings + stones
# 1.
# 1. Solution: Color-based segmentation: Keep just the green color pixels = Keep just the seedlings pixels
# 1.
# 1. Excepted result: Clean plant images without stones in the background. Ready to be fed to the model.

# %% [markdown]
# 1. Image preprocessing:¶
# 1. 2.1 Import the images
# 1. We start our image preprocessing by importing a Small-flowered Cranesbill image as a test image.

# %%
p1 = cv2.imread('/kaggle/input/v2-plant-seedlings-dataset/nonsegmentedv2/Small-flowered Cranesbill/135.png')
p1 = cv2.cvtColor(p1, cv2.COLOR_BGR2RGB)
plt.imshow(p1)
plt.grid(False)
plt.show()

# %% [markdown]
# 1. We will try to process this image in order to get rid of the unnecessary pixels. Feeding this picture to the model directly will result in a target leakage. The classifier will learn the stones and the container's pixels and build its prediction upon these pixels as well. This is something we would like to avoid.
# 1.
# 1. We start our preprocessing with simply segment an object from an image based on color using OpenCV. A popular computer vision library written in C/C++ with bindings for Python, OpenCV provides easy ways of manipulating color spaces [2].

# %%
def set_size(w,h, ax=None):
    """ w, h: width, height in inches """
    if not ax: ax=plt.gca()
    l = ax.figure.subplotpars.left
    r = ax.figure.subplotpars.right
    t = ax.figure.subplotpars.top
    b = ax.figure.subplotpars.bottom
    figw = float(w)/(r-l)
    figh = float(h)/(t-b)
    ax.figure.set_size_inches(figw, figh)
    
pixel_colors = p1.reshape((np.shape(p1)[0]*np.shape(p1)[1], 3))
norm = colors.Normalize(vmin=-1.,vmax=1.)
norm.autoscale(pixel_colors)
pixel_colors = norm(pixel_colors).tolist()

# %% [markdown]
# * 2.2 Visualize the plant image in RGB color space:¶
# * Here, we visualize the small-flowered Cranesbill image we opened above in RGB space to see the distributions of the color pixels.
# *
# * RGB is considered an “additive” color space, and colors can be imagined as being produced from shining quantities of red, blue, and green light onto a black background.

# %%
r, g, b = cv2.split(p1)
fig = plt.figure()
axis = fig.add_subplot(1, 1, 1, projection="3d")
set_size(6,6)
pixel_colors = p1.reshape((np.shape(p1)[0]*np.shape(p1)[1], 3))
norm = colors.Normalize(vmin=-1.,vmax=1.)
norm.autoscale(pixel_colors)
pixel_colors = norm(pixel_colors).tolist()

axis.scatter(r.flatten(), g.flatten(), b.flatten(), facecolors=pixel_colors, marker=".")
axis.set_xlabel("Red", weight='bold')
axis.set_ylabel("Green", weight='bold')
axis.set_zlabel("Blue", weight='bold')

plt.show()

# %% [markdown]
# 1. From this plot, you can see that the green parts of the image are mixed with the red and blue values. Segmenting our plant image out in RGB space based on ranges of RGB values would not be easy.
# 1.
# 1. The solution is to try another color space, we go next with HSV color space.

# %% [markdown]
# 1. 2.3 Visualize the plant image in HSV color space:
# 1. HSV stands for Hue, Saturation, and Value (or brightness), and is a cylindrical color space. The colors, or hues, are modeled as an angular dimension rotating around a central, vertical axis, which represents the value channel. Values go from dark (0 at the bottom) to light at the top. The third axis, saturation, defines the shades of hue from least saturated, at the vertical axis, to most saturated furthest away from the center:

# %%
hsv_p1 = cv2.cvtColor(p1, cv2.COLOR_RGB2HSV)

# %%
h, s, v = cv2.split(hsv_p1)
fig = plt.figure()
axis = fig.add_subplot(1, 1, 1, projection="3d")


axis.scatter(h.flatten(), s.flatten(), v.flatten(), facecolors=pixel_colors, marker=".")
axis.set_xlabel("Hue",weight='bold')
axis.set_ylabel("Saturation", weight='bold')
axis.set_zlabel("Value", weight='bold')
set_size(6,6)
plt.show()

# %% [markdown]
# Segmentation:¶
# 3.1 Color-based segmentation:
# To pick out a range color, we can use a color picking app online [3]. I found the green color ranges in a forum:
#
# minimum green(H=36, S=25, V=25)
# maximum green(H=70, S=255,V=255)
# We will use the openCV function cv2.inRange() to try to threshold our plant image with the minimum and maximum green values.
#
# inRange() takes three parameters: the image, the lower range, and the higher range. It returns a binary mask (an ndarray of 1s and 0s) the size of the image where values of 1 indicate values within the range, and zero values indicate values outside [2].

# %%
def plot_mask(image, colormin, colormax):
        hsv_p1 = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)   
        mask = cv2.inRange(hsv_p1, colormin , colormax)
        result = cv2.bitwise_and(image, image, mask=mask)
        plt.figure(figsize=(15,10))
        plt.subplot(1, 3, 1)
        plt.imshow(image)
        plt.grid(False)
        plt.subplot(1, 3, 2)
        plt.imshow(mask, cmap="gray")
        plt.grid(False)
        plt.subplot(1, 3, 3)
        plt.imshow(result)
        plt.grid(False)
        return plt.show()

# %%
colormin=(36, 25, 25)
colormax=(70, 255,255)

plot_mask(p1, colormin, colormax)

# %% [markdown]
# The result of our initial threshold is not bad, but we are missing some pixels of the plants. We will try to play manually with the saturation and brightness values to get a better a mask.

# %%
new_colormin=(25,50,50)
new_colormax=(80,255,255)
plot_mask(p1, new_colormin, new_colormax)

# %% [markdown]
# * Great! The segmentation looks fine. We got rid of the stones and the containers pixels. Let's apply this mask on the rest of pictures and visualize the results.
# *
# * 3.2 Segmentation function:
# * Now, we create a function that applies segmentation on the rest of the images. This function will be used to feed the computer vision model with the segmented images instead of the original ones.

# %%
def segmented(image):
    foto = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    hsv_foto = cv2.cvtColor(foto, cv2.COLOR_RGB2HSV)
    #print("hsvh",hsv_foto.dtype)
    colormin=(25,50,50)
    colormax=(86,255,255)

    mask = cv2.inRange(hsv_foto, colormin , colormax)
    #print("mask",mask.dtype)
    result = cv2.bitwise_and(foto, foto, mask=mask)
    #print("result",result.dtype)
    pil_image= Image.fromarray(result)


    return result

# %% [markdown]
#  Visualize the results of segmentation on the 12 plant species

# %%
plt.figure(figsize=(15,10))

for n in range(12):
        folder = subfolders[n]
        plt.subplot(3,4,n+1)
        files = listdir(Directory + folder + "/") 
        image=cv2.imread(Directory + folder + "/" + files[n+221])
        plt.imshow(segmented(image))
        plt.axis("off")
        plt.title(folder, weight='bold', fontsize=14)

# %%
def segmented2(image):
    image=np.array(image)

    hsv_foto = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
    colormin=(25,50,50)
    colormax=(90,255,255)
    mask = cv2.inRange(hsv_foto, colormin , colormax)
    
    result = cv2.bitwise_and(image, image, mask=mask)
    result2=np.array(result)



    return result2

# %% [markdown]
# 1. Computer vision model:¶
# 1. In this section, we will try to feed those plant images to a pretrained VGG19 convolutional neural network. We will train with both original and segmented images in order to find out the impact of the target leakage on training.

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        validation_split=0.15,
        preprocessing_function = segmented2
                     )

# %%
train_generator = train_datagen.flow_from_directory(
    '../input/v2-plant-seedlings-dataset/nonsegmentedv2',
        target_size=(64,64),
        batch_size=32,
        class_mode='categorical',
        subset='training')

validation_generator = train_datagen.flow_from_directory(
        '../input/v2-plant-seedlings-dataset/nonsegmentedv2',
        target_size=(64, 64),
        batch_size=32,
        class_mode='categorical',
        subset='validation')
# Out:
# Found 4714 images belonging to 12 classes.
# Found 825 images belonging to 12 classes.

# %%
# load pre-trained weights and add global average pooling layer
#base_model_incv3 = InceptionV3(weights=weights_incv3, input_shape=(150,150,3), include_top=False, pooling='avg')

# freeze convolutional layers
#for layer in base_model_incv3.layers:
#    layer.trainable = False

#define classification layers
#x = Dense(1024, activation='relu')(base_model_incv3.output)
#predictions = Dense(1, activation='sigmoid')(x)
#x = Dense(256, activation='relu')(base_model_incv3.output)
#x = Dropout(0.5)(x)
#predictions = Dense(12, activation='softmax')(x)

#model = Model(inputs=base_model_incv3.input, outputs=predictions)
#print(model.summary())

# %%
from keras.applications.vgg19 import VGG19
from keras.layers import Dropout
from keras.models import Sequential
from keras.layers import Dense, Flatten

# %%
vgg_conv = VGG19(weights='imagenet', include_top=False,pooling='avg', input_shape=(64, 64, 3))


model = Sequential()

model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(12, activation='softmax'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step

# %%
model.compile(Adam(lr=0.0001), loss='categorical_crossentropy', 
              metrics=['accuracy'])

# %%
# We'll stop training if no improvement after some epochs
earlystopper1 = EarlyStopping(monitor='loss', patience=5, verbose=1)

# Save the best model during the traning
checkpointer1 = ModelCheckpoint('best_model1.hdf5'
                                ,monitor='val_accuracy'
                                ,verbose=1
                                ,save_best_only=True
                                ,save_weights_only=True)

# %%
history = model.fit_generator(train_generator, steps_per_epoch=800, 
                    validation_data=validation_generator,
                    validation_steps=128,
                    epochs=5, verbose=1,
                   callbacks=[checkpointer1])
# Out:
# Epoch 1/5
# 148/800 [====>.........................] - ETA: 4:26 - loss: 2.4836 - accuracy: 0.1311
# Epoch 00001: val_accuracy improved from -inf to 0.13818, saving model to best_model1.hdf5
# 148/800 [====>.........................] - 71s 482ms/step - loss: 2.4836 - accuracy: 0.1311 - val_loss: 2.4822 - val_accuracy: 0.1382

# %%
plt.style.use('seaborn')
sns.set_style('whitegrid')
fig = plt.figure(figsize=(15,10))
#First Model
ax1 = plt.subplot2grid((2,2),(0,0))
train_loss = history.history['loss']
test_loss = history.history['val_loss']
x = list(range(1, len(test_loss) + 1))
plt.plot(x, test_loss, color = 'cyan', label = 'Test loss')
plt.plot(x, train_loss, label = 'Training losss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Model 1: Loss vs. Epoch',weight='bold', fontsize=18)
ax1 = plt.subplot2grid((2,2),(0,1))
train_acc = history.history['accuracy']
test_acc = history.history['val_accuracy']
x = list(range(1, len(test_acc) + 1))
plt.plot(x, test_acc, color = 'cyan', label = 'Test accuracy')
plt.plot(x, train_acc, label = 'Training accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Model 1: Accuracy vs. Epoch', weight='bold', fontsize=18)
plt.show()
